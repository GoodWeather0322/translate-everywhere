# %%
import sys
sys.path.append("/mnt/disk1/goodweather/translate-everywhere")

from core.end2end import End2End
# Out:
# /home/goodweather/anaconda3/envs/translate/lib/python3.12/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
model = End2End()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = End2End()
#
# File /mnt/disk1/goodweather/translate-everywhere/core/end2end.py:22, in End2End.__init__(self)
#      20 def __init__(self):
#      21     self.asr_model = AzureASR()
# ---> 22     self.translate_model = LLMTranslator()
#      23     self.tts_model = EdgeTTS()
#
# File /mnt/disk1/goodweather/translate-everywhere/core/translator.py:20, in LLMTranslator.__init__(self)
#      17 def __init__(self):
#      18     super().__init__()
# ---> 20     self.chat_model = ChatOllama(
#      21         base_url='http://localhost:11434',
#      22         model='llama3',
#      23         temperature=0,
#      24     )
#      26     self.multilingual_prompt_dict = {
#      27         "en" : 'How is the weather today',
#      28         'ja' : '今日の天気はどうですか',
#      29         'zh' : '今天的天氣如何',
#      30         'ko' : '방법 날씨가 오늘',
#      31     }
#      33     prompt_texts = [
#      34         """You are a helpful translator and only output the result in json format.\nEvery word should be carefully translated.\nTranslate this from <{source_language}> to <{target_language}>\n""",
#      35         """<{source_language}>:{source_sentence_example}\n""",
#      36         """<{target_language}>:{target_sentence_example}\n""",
#      37         """<{source_language}>:{source_sentence}\n""",
#      38     ]
#
# NameError: name 'ChatOllama' is not defined

# %%
final_text = model.end2end_flow('zh', 'ja', "test.mp3")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 final_text = model.end2end_flow('zh', 'ja', "test.mp3")
#
# NameError: name 'model' is not defined

# %%
final_text
# Out:
# '今日の昼食は何を食べますか？'
